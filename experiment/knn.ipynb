# %%
import sys
sys.path.append('../src')
from utilities import run_knn, load_human_action_dataset, load_ucr_dataset

# %%
alg = "DTW"          # algorithm
datatype = "UCR_TSL" # UCR_TSL for tslearn
out_file = f"{alg}.xlsx"


all_datasets = [
        "ArrowHead",              # AH
        "BasicMotions",           # BM
        "BeetleFly",              # BF
        "CBF",                    # CBF
        "Chinatown",              # CT
        "CinCECGTorso",           # CET
        "DiatomSizeReduction",    # DSR
        "GunPointAgeSpan",        # GPA
        "GunPointMaleVersusFemale", # GPM
        "GunPointOldVersusYoung", # GPO
        "Ham",                    # Ham
        "InsectEPGRegularTrain",  # IERT
        "ItalyPowerDemand",       # IPD
        "Meat",                   # Meat
        "MelbournePedestrian",    # MP
        "MixedShapesSmallTrain",  # MS2T
        "MoteStrain",             # MS
        "OliveOil",               # O2
        "Plane",                  # Plane
        "SmoothSubspace",         # S2
    ]

all_datasets = [s.replace("_UCR_TSL", "") for s in all_datasets]


run_knn('Weizmann', datatype, alg)
# Out:
# Successfully loaded dataset: Weizmann
# Size of train data: 40
# Size of test data: 40
# Test batches: 100%|██████████| 40/40 [03:11<00:00,  4.78s/it]
# Distance using: DTW
# Accuracy of 1NN: 45.00 %
# Accuracy of 3NN: 42.50 %
# Accuracy of 5NN: 40.00 %
# Accuracy of 10NN: 35.00 %
# Accuracy of 15NN: 27.50 %
# Accuracy of 30NN: 20.00 %
# Total runtime: 191.53 s
# ({1: 45.0, 3: 42.5, 5: 40.0, 10: 35.0, 15: 27.500000000000004, 30: 20.0},
#  191.5323350429535)
