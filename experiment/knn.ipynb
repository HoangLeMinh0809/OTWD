# %%
import sys
sys.path.append('../src')
from utilities import run_knn, load_human_action_dataset, load_ucr_dataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import sys
#       2 sys.path.append('../src')
# ----> 3 from utilities import run_knn, load_human_action_dataset, load_ucr_dataset
#
# File d:\OTWD\OTWD\experiment\../src\utilities.py:18
#      16 sys.path.append('src')
#      17 # from your_module import dtw_distance_series, taot_distance, gow_sinkhorn_autoscale
# ---> 18 import cupy as cp
#      20 # =========================
#      21 #  Loader UCR từ tslearn
#      22 # =========================
#      23 def load_ucr_dataset_tsl(data_dir, dataset_name):
#
# ModuleNotFoundError: No module named 'cupy'

# %%
alg = "OTSW"          # algorithm
datatype = "UCR_TSL" # Human_Actions or UCR_TSL for tslearn
out_file = f"{alg}.xlsx"


run_knn(dataset_name, datatype, alg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 32
#       6 all_datasets = [
#       7         "ArrowHead",              # AH
#       8         "BasicMotions",           # BM
#    (...)
#      26         "SmoothSubspace",         # S2
#      27     ]
#      29 all_datasets = [s.replace("_UCR_TSL", "") for s in all_datasets]
# ---> 32 run_knn('Weizmann', datatype, alg)
#
# NameError: name 'run_knn' is not defined
